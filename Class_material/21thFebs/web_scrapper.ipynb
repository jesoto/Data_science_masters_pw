# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcard_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipcard_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcard_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_html = bs(flipcart_page, 'html.parser')

# %%
"https://www.flipkart.com" + "/adsun-80-cm-32-inch-hd-ready-led-tv/p/itmffmnvusydzajr?pid=TVSFFMNVXFU4DFW4&lid=LSTTVSFFMNVXFU4DFW4CHQWEE&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&iid=en_0kdgvcCk6LL20j6NgFpH3%2BTgo0Rd0TqSsOo7agkV96pSdYFqxgXZMr7%2BkLQ%2BoGGxyaXAv%2F%2Fo17w0yLRvAcYatA%3D%3D&ssid=as1a4kon680000001680489244671&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/adsun-80-cm-32-inch-hd-ready-led-tv/p/itmffmnvusydzajr?pid=TVSFFMNVXFU4DFW4&lid=LSTTVSFFMNVXFU4DFW4CHQWEE&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&iid=en_0kdgvcCk6LL20j6NgFpH3%2BTgo0Rd0TqSsOo7agkV96pSdYFqxgXZMr7%2BkLQ%2BoGGxyaXAv%2F%2Fo17w0yLRvAcYatA%3D%3D&ssid=as1a4kon680000001680489244671&qH=c9a1fdac6e082dd8'

# %%
bigbox = flipcart_html.find_all('div',{"class" : "_1AtVbE col-12-12"})

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[0].div.div.div.a['href']

# %%
for i in range(len(bigbox)):
    print("https://www.flipkart.com" + bigbox[i].div.div.div.a['href'])
# Out:
# https://www.flipkart.com/adsun-frameless-80-cm-32-inch-hd-ready-led-smart-android-based-tv/p/itmdb08eafaa65fb?pid=TVSGAHZYMZNKZTUA&lid=LSTTVSGAHZYMZNKZTUAZYCLNZ&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_uzWWZfYKARxkdrSnfMHYMsLOw6DEpBDpPFEPHzCfyw%2BeAhM9lY25Ov89P%2FClUOWrx4CtziMHmCkV84lq02b2ZA%3D%3D&ppt=None&ppn=None&ssid=sp7uvbj0w00000001680489111123&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/oneplus-y1s-108-cm-43-inch-full-hd-led-smart-android-tv-11-bezel-less-frame/p/itm178846d2e1567?pid=TVSGAXEVSNT3HBQA&lid=LSTTVSGAXEVSNT3HBQAKRCYE0&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=e83766b7-8ae5-46ef-ac98-4352d7f9c374.TVSGAXEVSNT3HBQA.SEARCH&ppt=None&ppn=None&ssid=sp7uvbj0w00000001680489111123&qH=c9a1fdac6e082dd8
# ...

# %%
product_req = requests.get(productlink)

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commetbox = product_html.find_all('div', {'class' : '_16PBlm'})

# %%
len(commetbox)
# Out:
# 11

# %%
commetbox[0].div.div.find_all('p',{'class' : '_2sc7ZR _2V5EHH'})[0].text
# Out:
# 'Shiva'

# %%
#who comment
for i in commetbox : 
    print(i.div.div.find_all('p',{'class' : '_2sc7ZR _2V5EHH'})[0].text)
# Out:
# Shiva
# Flipkart Customer
# Lokesh GIRHARE
# Gaurav Vig
# Manoj  Yadav
# Deepak Pal
# Flipkart Customer
# Darshna Thakar
# Puneet Rana
# Thakur Anand kishor  Chauhan
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14724/46440612.py in <module>
#       1 for i in commetbox :
# ----> 2     print(i.div.div.find_all('p',{'class' : '_2sc7ZR _2V5EHH'})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
commetbox[0].div.div.div.div.text
# Out:
# '5'

# %%
#rating
for i in commetbox:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14724/3943357481.py in <module>
#       1 for i in commetbox:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
commetbox[0].div.div.div.p.text
# Out:
# 'Classy product'

# %%
#short comment
for i in commetbox:
    print(i.div.div.div.p.text)
# Out:
# Classy product
# Great product
# Terrific purchase
# Worth every penny
# Brilliant
# Wonderful
# Great product
# Worth the money
# Really Nice
# Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14724/2498719181.py in <module>
#       1 #short comment
#       2 for i in commetbox:
# ----> 3     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
commetbox[0].div.div.find_all('div', {'class': ""})[0].text
# Out:
# 'Nice tv.. Good clarity of picture.. @this cost it is very good tv.. But no installation done. Installation done by self..READ MORE'

# %%
#full comment
for i in commetbox:
    print(i.div.div.find_all('div', {'class': ""})[0].text)
# Out:
# Nice tv.. Good clarity of picture.. @this cost it is very good tv.. But no installation done. Installation done by self..READ MORE
# It's a good item.iloved.it superit's very good tv on screen mirroring wifi usb.   And support superb tv thankyou FlipkartREAD MORE
# Nice tv picture quality good & sound is to good screen minoring is not availableREAD MORE
# Nice product in such a low price range, good picture quality, good sound quality. Overall a good to buy in such a price range.READ MORE
# I'm happy with the service and installation. The product is awesome a great deal of price. The picture quality is good and sound is best this segment. The system is also used friendly. Completely satisfied with the product..READ MORE
# This product is very good quality.sound and all things is good and remote is better so I suggest that led tv because it's my country brand and all things is good and Nice product in such a low price range I am impressed.READ MORE
# ...
